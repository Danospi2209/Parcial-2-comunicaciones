# %%
import os
print("¡Entorno Jupyter precargado correctamente!")
print("Directorio de trabajo:", os.getcwd())

# %% [markdown]
# # Análisis de Datos - Parcial Comunicaciones
# Cuaderno precargado para procesamiento e inspección de datos.
